# %%
# 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install face_recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=0370f3f8e751c4d64ed61f26846e5de469a163a56114cdd4c2236709258c60e8
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/pix2pix/scripts')

# %%
# %run train.py
# Out:
# Epoch: 0, G_Loss: 57.363857, D_Loss: 0.820105, time: 0.12 min
# Epoch: 1, G_Loss: 54.853897, D_Loss: 0.827085, time: 0.13 min
# Epoch: 2, G_Loss: 52.688244, D_Loss: 0.923472, time: 0.15 min

# %%
# %run restore.py
